# %% [markdown]
# # 1. Crash Introduction to Python
#
# **Contents:**
#
# - First Python program
# - Variables and basic types
# - Operators
# - Type conversion
# - Strings and lists as sequences
# - Functions, conditions, and loops
# - Extra visualizations for teaching

# %% [markdown]
# ## 1.1. A Crash Example: GC content
#
# It demonstrates:
# - function definition
# - variables
# - a loop over a sequence
# - a conditional statement
# - a return value

# %%
def GC_content(dna_string):
    ''' calculate %GC in dna_string (uppercase ACTG) '''
    GC = 0
    for nuc in dna_string: # iterate over dna_string
        if nuc == "C" or nuc == "G":
            GC += 1 # equal to GC = GC+1
    return 100*GC/len(dna_string)

# %%
print(GC_content.__doc__)

# %%
GC_content("GT")

# %%
GC_content("CCG")

# %%
GC_content("TTAGACCAGTAGAAGTAC")

# %% [markdown]
# ## Explanation of the code
# ### Structure of the function
# - `def` starts a function definition
# - indentation defines the function body
# - the docstring describes the function
#
# ### Main logic
# - scan the DNA string one nucleotide at a time
# - count only `C` and `G`
# - divide by total length
# - multiply by 100 to get a percentage
#
# ### Self-checking questions
# - What happens on an empty string?
# - What happens on lowercase input?
# - Could we write the same idea in a different way?

# %% [markdown]
# ### Visualization: nucleotide histogram

# %%
from collections import Counter
import matplotlib.pyplot as plt

sample_dna = "TTAGACCAGTAGAAGTAC"
counts = Counter(sample_dna)

bases = ["A", "C", "G", "T"]
values = [counts.get(base, 0) for base in bases]

plt.figure(figsize=(7, 4))
plt.bar(bases, values, color=["blue", "orange", "green", "red"])
plt.title("Nucleotide counts in a sample DNA sequence")
plt.xlabel("Base")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # 1.2. Variables and basic types
#
# Python programs store data in variables.
#
# Built-in types:
#
# | Type/class | Meaning | Examples for values of this type |
# |---|---|---|
# | `int` | integer | `0`, `1`, `-1`, `2`, `-2`, `3`, `-3` |
# | `float` | rational number | `3.14`, `-0.001`, `8.0` |
# | `str` | string, sequence of characters | `"Amir"`, `"!!!"`, `"45"`, `"ATTCG"` |
# | `list` | sequence of elements | `[1, 2, 3]`, `[55, "hello", 55, -7]` |
# | `bool` | Boolean | `True`, `False` |

# %%
x = 5
type(x)

# %%
y = 0.001
type(y)

# %%
type(True)

# %%
s1 = "drosophila"
type(s1)

# %%
type("45")

# %%
bases = ["A", "C", "G", "T"]
type(bases)

# %% [markdown]
# ## Dynamic typing
#
# In Python:
# - variables are not declared with a fixed type
# - a variable may later store a value of a different type
#
# This is often very convenient for beginners, because the notation stays simple.

# %%
x = 5
type(x)

# %%
x= 5.1
type(x)

# %%
x = "5.1"
type(x)

# %% [markdown]
# ## Numeric operators
#
# | Operator | Symbol | Example |
# |---|---|---|
# | Addition | `+` | `x+y` |
# | Subtraction | `-` | `x-y` |
# | Negation | `-` | `-x` |
# | Multiplication | `*` | `x*y` |
# | Division | `/` | `x/y` |
# | Floor division | `//` | `x//y` |
# | Exponentiation | `**` | `x**y` |
# | Modulo | `%` | `x%y` |

# %% [markdown]
# ## What will be the output?

# %%
8/5

# %%
8//5

# %%
8%5

# %%
3*4+5

# %%
3*(4+5)

# %%
2*3

# %%
2**3

# %% [markdown]
# # 1.3. Comparison, logical operators and assignment
#
# ### Comparison operators
#
# | Operator | Symbol | Example |
# |---|---|---|
# | Equal | `==` | `x == y` |
# | Unequal | `!=` | `x != y` |
# | Less than | `<` | `x < y` |
# | Less or equal | `<=` | `x <= y` |
# | Greater than | `>` | `x > y` |
# | Greater or equal | `>=` | `x >= y` |
#
# ### Boolean operators
#
# | Operator | Usage | When this expression is True |
# |---|---|---|
# | `and` | `A and B` | both `A` and `B` are `True` |
# | `or` | `A or B` | at least one of `A` and `B` is `True` |
# | `not` | `not A` | `A` is `False` |

# %% [markdown]
# ## What will be the output?

# %%
x = 3
y = 4

x == y

# %%
x == y-1

# %%
x < y

# %%
x == 3 and x == y

# %%
x == y or x == y-1

# %%
not (x == y or x == y-1)

# %%
x != y and x != y-1

# %%
# are these two statements equivalent?
print(not (x == x or y == y)) # with parentheses 
print(not x == x or y == y)   # without parentheses

# %% [markdown]
# ## Strings are comparable
# Python compares strings lexicographically (like in a dictionary).

# %%
"A" < "C"

# %%
"drosophila" < "chromosome"

# %%
"AA" < "AAA"

# %%
"acgt" == "ACGT"

# %%
"acgt" != "ACGT"

# %% [markdown]
# ## Assignment operator
# What will be the output?

# %%
# assignment operator
x = 0
x += 1  # short hand for x = x + 1
print(x)

# %%
x *= 2  # short hand for x = x * 2
print(x)

# %%
x **= 3 
print(x)

# %%
x /= 2
print(x)

# %% [markdown]
# ## Assignment operator with strings

# %%
seq = "AGCT-"
seq += "CTGA"  # short hand for seq = seq + "CTGA"
print(seq)

# %% [markdown]
# # 1.4. Type conversions
#
# Python supports explicit conversion between some types.
#
# Explicit conversion functions:
# - `int(...)`
# - `float(...)`
# - `str(...)`
# - `list(...)`

# %%
x = 5.2
int(x)

# %%
x = 5.9
int(x)

# %%
y = 8
float(y)

# %%
str(56)

# %%
int("34")

# %%
int("AGCT")

# %% [markdown]
# ## What will be the output?

# %%
x = 1.2 + 0.8
type(x)

# %%
x = 10 * 0.1
type(x)

# %%
x = 10 / 2
type(x)

# %%
x = 10 // 2
type(x)

# %% [markdown]
# ## Conversion between string and list

# %%
# Conversion from string to list creates a list of characters
list("AGCTGGA")

# %%
# Conversion from list to string requires join method of string class
bases = ["A", "C", "G", "T"]
"".join(bases) # concatenates the elements of the list into a single string, with "" as the separator

# %%
"-".join(bases) # concatenates the elements of the list into a single string, with "-" as the separator

# %% [markdown]
# # 1.5. Strings and lists as sequences
# - String is a sequence of characters.
# - List is a sequence of elements (of any type).
#
# Both strings and lists support sequence operations.
#
# | Operator | Symbol | Example for strings | Example for lists |
# |---|---|---|---|
# | Concatenation | `+` | `"droso" + "phila"` | `[1,2,3] + [4,5]` |
# | Replication | `*` | `"UAG" * 8` | `["a",4] * 3` |

# %% [markdown]
# ## List concatenation with + operator

# %%
# List concatenation with + operator
positive_aa = ["Lysine", "Arginine"]
negative_aa = ["Aspartic acid", "Glutamic acid"]
charged = positive_aa + negative_aa
charged

# %% [markdown]
# ## String concatenation with + operator

# %%
# String concatenation with + operator
dna = ""
dna += "AGCT"
dna += "GGA"
dna

# %% [markdown]
# ## List replication with * operator

# %%
codons = ["AUG", "UUU", "GGC"]
codons * 3

# %% [markdown]
# ## String replication with * operator

# %%
motif = "ATG_"
motif * 4

# %% [markdown]
# ## Indexing
# Use `[i]` to access the i-th element of a sequence (0-based indexing).

# %%
organism = "drosophila"
organism[0]

# %%
organism[5]

# %%
organism[10] # IndexError: string index out of range

# %%
len(organism) # returns the length of the string

# %% [markdown]
# ## Who to get the last element of a string?

# %%
organism[len(organism)-1] # last character of the string

# %%
# Negative indexing counts from the end of the string
organism[-1] # last character of the string

# %% [markdown]
# ## Who to get the first character of a string using negative indexing?

# %%
# getting the first element of the string using negative indexing
organism[-len(organism)] # first character of the string

# %% [markdown]
# ## Multidimensional indexing
# Useful for tables and matrices

# %%
# matrix is a list of lists
# each inner list represents a row of the matrix
matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]] 

print(matrix[0]) # first row of the matrix
print(matrix[0][0]) # first element of the first row of the matrix
print(matrix[0][1]) # second element of the first row of the matrix
print(matrix[0][2]) # third element of the first row of the matrix

# %%
matrix[2][2] # the last element of the last row of the matrix

# %% [markdown]
# ## What is the output of this code?

# %%
matrix = [[1, 2, 3], [4, 5, 6]] 
print(len(matrix))
print(len(matrix[0]))

# %% [markdown]
# ## Slicing
# Use `[i:j]` to get a slice of a sequence from index `i` (inclusive) to `j` (exclusive).
# The resulting slice contains elements with indices `i, i+1, ..., j-1`.

# %%
organism = "drosophila"
organism[0:4]

# %%
organism[0:1] # returns the first character of the string

# %%
organism[0:len(organism)] # returns the entire string

# %%
organism[ : ] # returns the entire string

# %%
organism[:: 2] # returns every second character of the string

# %%
organism[::-1] # returns the string in reverse order

# %% [markdown]
# ## Membership test for strings and lists
# Use `in` to check if a substring is present in a string, or if an element is present in a list.

# %%
organism = "drosophila"
print("p" in organism)
print("phila" in organism)
print("x" in organism)

# %%
print(1 in [1,2,3])
print("1" in [1,2,3])

# %% [markdown]
# ## Lists are mutable, strings are not
# We can change elements in lists, but not in strings

# %%
lst = ["T", "A", "A", "T", "A"]
lst[0] = "-"
lst

# %%
dna = "TAATA"
dna[0] = "-" # Error: strings are not mutable

# %% [markdown]
# ## What will be the output of this code?

# %%
Glycine_codons = ["GGU", "GGC", "GGA", "GGG"]
Glycine_codons [3] = "ggg"
Glycine_codons [3][2] = "-"
Glycine_codons

# %% [markdown]
# ## How to modify a string?
#  To change a character in a string, we can convert the string to a list,
#  modify the list, and then convert it back to a string

# %%
dna = "TAATA"
dna_list = list(dna)
dna_list[1] = "-"
dna = "".join(dna_list)
dna

# %% [markdown]
# # 1.6. Functions
# Functions are reusable pieces of code that perform a specific task.
# - Built-in functions: `print()`, `len()`, `int()`, `str()`, etc. Can be used without definition.
# - User-defined functions: defined by the programmer using `def` keyword.

# %% [markdown]
# ## 1.6.1. Built-in functions
# Build-in functions are part of the Python language and are always available. For example: `len(...)`, `max(...)`, `min(...)`, `sum(...)`, `sorted(...)`, `range(...)`.

# %%
# min, max, and sum can be used on lists of numbers
values = [1, 2, 3, 4, 5]
print("min:", min(values))
print("max:", max(values))
print("sum:", sum(values))

# %%
# min and max also work with strings, 
# based on lexicographical order (dictionary order)
print("min: ", min(["cat", "dog", "bee"]))
print("max: ", max(["cat", "dog", "bee"]))

# %% [markdown]
# ## Built-in function `sorted(...)`
# Function `sorted(...)` returns a sorted version of a sequence (string or list), without modifying the original sequence.

# %%
values = [ 10, -1, 7, -12, 18, 0]
print("sorted values:", sorted(values))
print("original values:", values) # note that the original list is unchanged

# %% [markdown]
# ## 1.6.2. User-defined functions
# User-defined functions are defined by the programmer to perform specific tasks. They are created using the `def` keyword, followed by the function name and parameters.

# %%
# Function definition:
def CG_content(dna_string):
    ''' calculate %GC in dna_string (uppercase ACTG) ''' # docstring: a string that describes the function
    # function body: the code that performs the calculation
    # note the indentation ( <tab> ) of the function body
    GC = 0
    for nuc in dna_string: # iterate over dna_string
        if nuc == "C" or nuc == "G":
            GC += 1 # equal to GC = GC+1
    return 100*GC/len(dna_string)   # return value

# Function call:
print(CG_content("GT"))

# Function return value can be assigned to a variable for later use:
result = CG_content("ATGCGTAAGGDTAGTAAGGTAAGGTAAGGC")
print(result)

# %% [markdown]
# ## 1.6.3. Class Methods
# In addition to the built-in and user-defined function, additional sources for functions are class
# methods. These are functions that belong to specific classes in Python. For example, there are
# methods that belong to the class of strings.

# %%
# Count the number of occurrences of "G" and "A" 
dna = "ATGCGTAAGGDTAGTAAGGTAAGGTAAGGC"
print('''dna.count("G") :''', dna.count("G")) # built-in string method to count the number of occurrences of "G" in the string
print('''dna.count("A") :''', dna.count("A"))

# %%
# String methods do not modify the original string, 
# they return a new string
print('''dna.lower() :          ''', dna.lower()) # built-in string method to convert the string to lowercase
print('''dna remains unchanged: ''', dna) # note that the original string is unchanged

# %%
# Replace all occurrences of "A" with "-" in the string
# Note that this does not modify the original string, 
# it returns a new string with the replacements
print('''dna.replace("A", "-") :''', dna.replace("A", "-")) # built-in string method to replace all occurrences of "D" with "A" in the string
print('''dna remains unchanged: ''', dna) # note that the original string is unchanged

# %%
# Find the index of the first occurrence of a substring in the string
print('''dna :            ''', dna)
print('''dna.find("G") :  ''', dna.find("G")) # built-in string method to find the index of the first occurrence of "A" in the string
print('''dna.find("TAA") :''', dna.find("TAA"))
print('''dna.find("X") :  ''', dna.find("X")) # returns -1 if the substring is not found in the string

# %% [markdown]
# ## Methods of class `list`
#
# - `count(...)`: counts the number of occurrences of an element in the list
# - `append(...)`: adds an element to the end of the list
# - `insert(...)`: inserts an element at a specific position in the list
# - `pop(...)`: removes and returns an element at a specific position in the list
# - `remove(...)`: removes the first occurrence of an element from the list
# - `reverse()`: reverses the order of elements in the list
# - `sort()`: sorts the elements of the list in place
#
# Examples:

# %%
lst = [3, 1, 2, 3, 1, 0, 4, 1]
lst.count(1)

# %%
lst.append(5) # appends 5 to the end of the list
print(lst)

# %%
lst.insert(0, 100) # inserts 100 at index 0 of the list
print(lst)

# %%
lst.pop(0) # removes and returns the element at index 0 of the list
print(lst)

# %%
lst.remove(3) # removes the first occurrence of 3 from the list
print(lst)

# %%
lst.sort() # sorts the list in place
print(lst)

# %%
lst.reverse() # reverses the list in place
print(lst)

# %% [markdown]
# ## Getting the list of available methods for a class
# - `help(str)` or `dir(str)` to get the list of methods for strings
# - `help(list)` or `dir(list)` to get the list of methods for lists

# %%
help(str) # built-in function to get help on the str class and its methods

# %%
help(str.replace) # built-in function to get help on the replace method of the str class

# %% [markdown]
# ## Functions can call other functions

# %%
def GC_content(dna_string):
    '''calculate %GC in dna_string (uppercase ACTG)'''
    C_count = dna_string.count("C")
    G_count = dna_string.count("G")
    return 100*(C_count + G_count)/len(dna_string)

# %%
CG_content("AGTCGTAGTAATTAGGTAATTAGAATTAG")

# %% [markdown]
# What will be the output of this code?

# %%
CG_content("AGTCGTAGTAATTAGGTAATTAGAATTAG".lower())

# %% [markdown]
# ## 1.6.4. Return value(s)
# A function can return a value using the `return` statement. If no `return` statement is present, the function returns `None` by default.

# %%
# Function to modify a list by changing the value at a specific index
def modify(list, i, value):
    list[i] = value
    return None

# %%
list = [1, 2, 3, 4, 5]
res = modify(list, 0, 100)
print("modified list:                    ", list) # note that the original list is modified
print("return value of modify function:  ", res) # the function returns None, which is the default return value of a function that does not have a return statement
# Out:
# modified list:                     [100, 2, 3, 4, 5]
# return value of modify function:   None

# %% [markdown]
# # 1.7. Conditional statements
#
# Conditionals split the program into alternative execution paths.
#
# Example:

# %%
def state(Tm, Tv, T):
    ''' return the state of material with Tm and Tv at temperature T '''
    if T < Tm:
        return "solid"
    else:
        if T < Tv:
            return "liquid"
        else:
            return "gas"

# %%
state(0, 100, 25)

# %% [markdown]
# ### Main keypoints
# - `if` checks a condition
# - `else` gives the alternative branch
# - indentation determines which statements belong to each branch

# %% [markdown]
# ## Iteration with `for` loops
#
# The chapter introduces `for` loops as a natural way to iterate over strings and lists.

# %%
def basic_aa_perc(prot):
    ''' return percentage of basic amino acids in protein '''
    basic = 0
    basic_aa_list = ["K", "H", "R"]
    for aa in prot:
        if aa in basic_aa_list:
            basic += 1
    return 100*basic/len(prot)

# %%
basic_aa_perc("MHKRAGG")

# %% [markdown]
# ## Iteration with `while` loops
#
# A `while` loop repeats as long as a condition remains true.
#
# This version rewrites GC content with an explicit running index.

# %%
def GC_content3(dna_string):
    ''' calculate %GC in dna string (uppercase ACTG) '''
    GC = 0
    i = 0
    while i < len(dna_string):
        if dna_string[i] == "C" or dna_string [i] == "G":
            GC += 1
        i += 1
    return 100*GC/len(dna_string)

# %%
GC_content3("TTAGACCAGTAGAAGTAC")

# %% [markdown]
# ## Summary of the chapter
#
# By this point, students have seen:
#
# - function definitions
# - variables and built-in types
# - numeric, comparison, and logical operators
# - type conversion
# - strings and lists as sequences
# - indexing and slicing
# - return values
# - conditional statements
# - `for` loops and `while` loops
#
# This is a strong foundation for later topics in biological computation.

# %% [markdown]
# ## Suggested short in-class questions
#
# 1. Why does `GC_content` use a loop?
# 2. How is `x == y` different from `x = y`?
# 3. What is the difference between `/` and `//`?
# 4. Why is indexing zero-based?
# 5. When is `while` more natural than `for`?
# 6. How do visualizations help us understand sequence-processing code?

# %% [markdown]
# ## End of slideshow
